# %% [markdown]
# ### Dataset normalization.
# - Convert DN value to reflectance

# %%
import os 
import numpy as np
import rasterio as rio 
from glob import glob
import geopandas as gpd
import cartopy.crs as ccrs
from pyrsimg import imsShow
from rasterio import features
import matplotlib.pyplot as plt
from shapely.geometry import Point
import cartopy.feature as cfeature 
from notebooks import config

# %%
### get the secene and truth pairwise data
paths_scene = sorted(glob('data/dset/scene/scene_ori/*/*.tif'))
paths_truth = sorted(glob('data/dset/truth/truth_tif/*/*.tif'))
print(len(paths_scene))
print(len(paths_truth))
# Out:
# 214
# 214

# %%
def normalize_dn2ref(image, scale=0.0001, offset=0):
    '''
    des: convert DN to reflectance
    args:  numpy array
    '''
    image_nor = image.astype(np.float32) * scale + offset
    image_nor = np.clip(image_nor, 0.0, 1.0)
    return image_nor

# %%
for path_scene in paths_scene:
    path_save = path_scene.replace('scene_ori/', 'scene_nor/')
    scene_sat = path_scene.split('/')[-1][0:2]
    scene_rio = rio.open(path_scene)
    profile = scene_rio.profile.copy()
    profile.update(dtype='float32')
    scene_nor = normalize_dn2ref(image=scene_rio.read(), 
                       scale=config.scale[scene_sat], 
                       offset=config.offset[scene_sat])

    # write to disk
    if os.path.exists(path_save): os.remove(path_save)
    with rio.open(path_save, 'w', **profile) as dst:
        dst.write(scene_nor.astype('float32'))
    print(f'Wrote normalized scene to: {path_save}')
    # break
# Out:
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_01.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_02.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_03.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_04.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_05.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_06.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_07.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_08.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_09.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_10.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_11.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_12.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_13.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_14.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_15.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_16.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_17.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_18.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_19.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_20.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_21.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_22.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_23.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_24.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_25.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_26.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_27.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_28.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_29.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l5/l5_scene_30.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_01.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_02.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_03.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_04.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_05.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_06.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_07.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_08.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_09.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_10.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_11.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_12.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_13.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_14.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_15.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_16.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_17.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_18.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_19.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_20.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_21.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_22.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_23.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_25.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_26.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_27.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_28.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_29.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l7/l7_scene_30.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_01.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_02.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_03.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_04.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_05.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_06.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_07.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_08.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_09.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_10.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_11.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_12.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_13.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/l8/l8_scene_14.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/
tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2A_L2A_20190817_N0213_R089_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2A_L2A_20190817_N0213_R089_6Bands_S4.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2A_L2A_20190830_N0213_R133_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2A_L2A_20190830_N0213_R133_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2A_L2A_20190830_N0213_R133_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20181226_N0211_R102_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20181226_N0211_R102_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20181226_N0211_R102_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190225_N0211_R117_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190225_N0211_R117_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190225_N0211_R117_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190303_N0211_R065_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190303_N0211_R065_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190303_N0211_R065_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190430_N0211_R035_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190430_N0211_R035_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190430_N0211_R035_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190506_N0212_R126_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190506_N0212_R126_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190506_N0212_R126_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190607_N0212_R012_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190607_N0212_R012_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190607_N0212_R012_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190620_N0212_R047_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190620_N0212_R047_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190620_N0212_R047_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190620_N0212_R053_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190620_N0212_R053_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190620_N0212_R053_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190801_N0213_R084_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190801_N0213_R084_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190801_N0213_R084_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190807_N0213_R018_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190807_N0213_R018_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190807_N0213_R018_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190811_N0213_R079_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190811_N0213_R079_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190811_N0213_R079_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190818_N0213_R035_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190818_N0213_R035_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190818_N0213_R035_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190831_N0213_R082_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190831_N0213_R082_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190831_N0213_R082_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190904_N0213_R132_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190904_N0213_R132_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190904_N0213_R132_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190912_N0213_R102_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190912_N0213_R102_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20190912_N0213_R102_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20191015_N0213_R007_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20191015_N0213_R007_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20191015_N0213_R007_6Bands_S3.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20191023_N0213_R121_6Bands_S1.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20191023_N0213_R121_6Bands_S2.tif
# Wrote normalized scene to: data/dset/scene/scene_nor/s2/S2B_L2A_20191023_N0213_R121_6Bands_S3.tif

# %%
id = 95
path_scene = paths_scene[id]
print(path_scene)
path_scene_nor = path_scene.replace('scene_ori/', 'scene_nor/')
scene_rio, scene_nor_rio = rio.open(path_scene), rio.open(path_scene_nor)
fig, ax = plt.subplots(1, 2, figsize=(8, 3))
ax[0].hist(scene_rio.read(1).flatten(), bins=100, color='blue');
ax[0].set_title('original scene');
ax[1].hist(scene_nor_rio.read(1).flatten(), bins=100, color='orange');
ax[1].set_title('normalized scene');
plt.tight_layout()
# Out:
# data/dset/scene/scene_ori/l9/l9_scene_07.tif

# %%
imsShow([scene_rio.read().transpose(1, 2, 0), 
                scene_nor_rio.read().transpose(1, 2, 0)], 
                clip_list=[1, 1], 
                color_bands_list=[[3, 2, 1], [3, 2, 1]],
                figsize=(9, 5));
