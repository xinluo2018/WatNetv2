# %% [markdown]
# ### Dataset splitting
# - split dataset into traset and valset.

# %%
import numpy as np
import rasterio as rio 
from glob import glob
import geopandas as gpd
import cartopy.crs as ccrs
from pyrsimg import imgShow
from rasterio import features
import matplotlib.pyplot as plt
from shapely.geometry import Point
import cartopy.feature as cfeature 
from notebooks import config

# %%
### get the secene and truth pairwise data
paths_scene = sorted(glob(config.dir_scene+'*/*.tif'))
paths_truth = sorted(glob(config.dir_truth+'*/*.tif'))
print(len(paths_scene))
print(len(paths_truth))
# Out:
# 214
# 214

# %% [markdown]
# #### 2. dataset split into traset and valset

# %%
ids_scene = [path.split('/')[-1].split('.')[0] for path in paths_scene] 
ids_scene_val = sorted(ids_scene)[::5]  ## every 5th scene for validation
ids_scene_tra = sorted(list(set(ids_scene) - set(ids_scene_val)))
print(f'train data: {len(ids_scene_tra)}, vali data: {len(ids_scene_val)}')
print('train scene ids:', ids_scene_tra)  
print('vali scene ids:', ids_scene_val)
# Out:
# train data: 171, vali data: 43
# train scene ids: ['S2A_L2A_20190125_N0211_R034_6Bands_S2', 'S2A_L2A_20190125_N0211_R034_6Bands_S3', 'S2A_L2A_20190206_N0211_R067_6Bands_S1', 'S2A_L2A_20190206_N0211_R067_6Bands_S2', 'S2A_L2A_20190314_N0211_R008_6Bands_S1', 'S2A_L2A_20190314_N0211_R008_6Bands_S2', 'S2A_L2A_20190314_N0211_R008_6Bands_S3', 'S2A_L2A_20190318_N0211_R061_6Bands_S1', 'S2A_L2A_20190318_N0211_R061_6Bands_S3', 'S2A_L2A_20190426_N0211_R053_6Bands_S1', 'S2A_L2A_20190426_N0211_R053_6Bands_S2', 'S2A_L2A_20190426_N0211_R053_6Bands_S3', 'S2A_L2A_20190429_N0211_R096_6Bands_S2', 'S2A_L2A_20190429_N0211_R096_6Bands_S3', 'S2A_L2A_20190508_N0212_R078_6Bands_S1', 'S2A_L2A_20190508_N0212_R078_6Bands_S2', 'S2A_L2A_20190518_N0212_R073_6Bands_S1', 'S2A_L2A_20190518_N0212_R073_6Bands_S2', 'S2A_L2A_20190518_N0212_R073_6Bands_S3', 'S2A_L2A_20190716_N0213_R063_6Bands_S1', 'S2A_L2A_20190716_N0213_R063_6Bands_S3', 'S2A_L2A_20190724_N0213_R033_6Bands_S1', 'S2A_L2A_20190724_N0213_R033_6Bands_S2', 'S2A_L2A_20190724_N0213_R033_6Bands_S3', 'S2A_L2A_20190725_N0213_R054_6Bands_S2', 'S2A_L2A_20190725_N0213_R054_6Bands_S3', 'S2A_L2A_20190725_N0213_R054_6Bands_S4', 'S2A_L2A_20190811_N0213_R013_6Bands_S1', 'S2A_L2A_20190811_N0213_R013_6Bands_S3', 'S2A_L2A_20190817_N0213_R089_6Bands_S1', 'S2A_L2A_20190817_N0213_R089_6Bands_S2', 'S2A_L2A_20190817_N0213_R089_6Bands_S3', 'S2A_L2A_20190830_N0213_R133_6Bands_S1', 'S2A_L2A_20190830_N0213_R133_6Bands_S2', 'S2A_L2A_20190830_N0213_R133_6Bands_S3', 'S2B_L2A_20181226_N0211_R102_6Bands_S1', 'S2B_L2A_20181226_N0211_R102_6Bands_S3', 'S2B_L2A_20190225_N0211_R117_6Bands_S1', 'S2B_L2A_20190225_N0211_R117_6Bands_S2', 'S2B_L2A_20190225_N0211_R117_6Bands_S3', 'S2B_L2A_20190303_N0211_R065_6Bands_S2', 'S2B_L2A_20190303_N0211_R065_6Bands_S3', 'S2B_L2A_20190430_N0211_R035_6Bands_S1', 'S2B_L2A_20190430_N0211_R035_6Bands_S2', 'S2B_L2A_20190506_N0212_R126_6Bands_S1', 'S2B_L2A_20190506_N0212_R126_6Bands_S2', 'S2B_L2A_20190506_N0212_R126_6Bands_S3', 'S2B_L2A_20190607_N0212_R012_6Bands_S1', 'S2B_L2A_20190607_N0212_R012_6Bands_S3', 'S2B_L2A_20190620_N0212_R047_6Bands_S1', 'S2B_L2A_20190620_N0212_R047_6Bands_S2', 'S2B_L2A_20190620_N0212_R047_6Bands_S3', 'S2B_L2A_20190620_N0212_R053_6Bands_S2', 'S2B_L2A_20190620_N0212_R053_6Bands_S3', 'S2B_L2A_20190801_N0213_R084_6Bands_S1', 'S2B_L2A_20190801_N0213_R084_6Bands_S2', 'S2B_L2A_20190807_N0213_R018_6Bands_S1', 'S2B_L2A_20190807_N0213_R018_6Bands_S2', 'S2B_L2A_20190807_N0213_R018_6Bands_S3', 'S2B_L2A_20190811_N0213_R079_6Bands_S1', 'S2B_L2A_20190811_N0213_R079_6Bands_S3', 'S2B_L2A_20190818_N0213_R035_6Bands_S1', 'S2B_L2A_20190818_N0213_R035_6Bands_S2', 'S2B_L2A_20190818_N0213_R035_6Bands_S3', 'S2B_L2A_20190831_N0213_R082_6Bands_S2', 'S2B_L2A_20190831_N0213_R082_6Bands_S3', 'S2B_L2A_20190904_N0213_R132_6Bands_S1', 'S2B_L2A_20190904_N0213_R132_6Bands_S2', 'S2B_L2A_20190912_N0213_R102_6Bands_S1', 'S2B_L2A_20190912_N0213_R102_6Bands_S2', 'S2B_L2A_20190912_N0213_R102_6Bands_S3', 'S2B_L2A_20191015_N0213_R007_6Bands_S1', 'S2B_L2A_20191015_N0213_R007_6Bands_S3', 'S2B_L2A_20191023_N0213_R121_6Bands_S1', 'S2B_L2A_20191023_N0213_R121_6Bands_S2', 'S2B_L2A_20191023_N0213_R121_6Bands_S3', 'l5_scene_02', 'l5_scene_03', 'l5_scene_04', 'l5_scene_05', 'l5_scene_07', 'l5_scene_08', 'l5_scene_09', 'l5_scene_10', 'l5_scene_12', 'l5_scene_13', 'l5_scene_14', 'l5_scene_15', 'l5_scene_17', 'l5_scene_18', 'l5_scene_19', 'l5_scene_20', 'l5_scene_22', 'l5_scene_23', 'l5_scene_24', 'l5_scene_25', 'l5_scene_27', 'l5_scene_28', 'l5_scene_29', 'l5_scene_30', 'l7_scene_02', 'l7_scene_03', 'l7_scene_04', 'l7_scene_05', 'l7_scene_07', 'l7_scene_08', 'l7_scene_09', 'l7_scene_10', 'l7_scene_12', 'l7_scene_13', 'l7_scene_14', 'l7_scene_15', 'l7_scene_17', 'l7_scene_18', 'l7_scene_19', 'l7_scene_20', 'l7_scene_22', 'l7_scene_23', 'l7_scene_25', 'l7_scene_26', 'l7_scene_28', 'l7_scene_29', 'l7_scene_30', 'l8_scene_01', 'l8_scene_03', 'l8_scene_04', 'l8_scene_05', 'l8_scene_06', 'l8_scene_08', 'l8_scene_09', 'l8_scene_10', 'l8_scene_11', 'l8_scene_13', 'l8_scene_1 ...
# vali scene ids: ['S2A_L2A_20190125_N0211_R034_6Bands_S1', 'S2A_L2A_20190206_N0211_R067_6Bands_S3', 'S2A_L2A_20190318_N0211_R061_6Bands_S2', 'S2A_L2A_20190429_N0211_R096_6Bands_S1', 'S2A_L2A_20190508_N0212_R078_6Bands_S3', 'S2A_L2A_20190716_N0213_R063_6Bands_S2', 'S2A_L2A_20190725_N0213_R054_6Bands_S1', 'S2A_L2A_20190811_N0213_R013_6Bands_S2', 'S2A_L2A_20190817_N0213_R089_6Bands_S4', 'S2B_L2A_20181226_N0211_R102_6Bands_S2', 'S2B_L2A_20190303_N0211_R065_6Bands_S1', 'S2B_L2A_20190430_N0211_R035_6Bands_S3', 'S2B_L2A_20190607_N0212_R012_6Bands_S2', 'S2B_L2A_20190620_N0212_R053_6Bands_S1', 'S2B_L2A_20190801_N0213_R084_6Bands_S3', 'S2B_L2A_20190811_N0213_R079_6Bands_S2', 'S2B_L2A_20190831_N0213_R082_6Bands_S1', 'S2B_L2A_20190904_N0213_R132_6Bands_S3', 'S2B_L2A_20191015_N0213_R007_6Bands_S2', 'l5_scene_01', 'l5_scene_06', 'l5_scene_11', 'l5_scene_16', 'l5_scene_21', 'l5_scene_26', 'l7_scene_01', 'l7_scene_06', 'l7_scene_11', 'l7_scene_16', 'l7_scene_21', 'l7_scene_27', 'l8_scene_02', 'l8_scene_07', 'l8_scene_12', 'l8_scene_17', 'l8_scene_22', 'l8_scene_27', 'l9_scene_02', 'l9_scene_07', 'l9_scene_12', 'l9_scene_17', 'l9_scene_22', 'l9_scene_27']

# %%
# get the paths for training and validation sets 
paths_truth_tra = [config.dir_truth+f'{id}.tif' for id in ids_scene_tra]
paths_truth_val = [config.dir_truth+f'{id}.tif' for id in ids_scene_val]
paths_truth_tra[10]
# Out:
# 'data/dset/truth/truth_tif/S2A_L2A_20190426_N0211_R053_6Bands_S2.tif'

# %%
import rasterio
from rasterio.warp import transform

def get_image_center_wgs84(path_tif):
    scene_id = path_tif.split('/')[-1].split('.')[0] 
    with rasterio.open(path_tif) as src:
        center_x = src.width / 2
        center_y = src.height / 2
        center_lon, center_lat = src.xy(center_y, center_x)        
        center = (center_lon, center_lat)
        if src.crs and src.crs.to_epsg() != 4326:
            from_crs = src.crs.to_string()
            to_crs = "EPSG:4326"  # WGS84
            lon, lat = transform(from_crs, to_crs, [center_lon], [center_lat])
            center = (lon[0], lat[0])
            return center, scene_id
        else:
            return center, scene_id

# %%
paths_truth_tif = sorted(glob(config.dir_truth+'*/*.tif')) 
scene_centers, scene_ids = zip(*[get_image_center_wgs84(path) for path in paths_scene])
print(scene_ids[0], scene_centers[0])
# Out:
# l5_scene_01 (119.5704867729241, -29.095217192439915)

# %%
dset_gdf = gpd.GeoDataFrame({
  'scene_id': [scene_id for scene_id in scene_ids],
  'satellite': [scene_id[0:2] for scene_id in scene_ids],
  'tra': [True if scene_id in ids_scene_tra else False for scene_id in scene_ids],
  'geometry': [Point(center) for center in scene_centers],
      }, 
  crs='EPSG:4326')
# dset_gdf.to_file('data/dset/dset.gpkg', driver='GPKG') 
dset_gdf.head(5)
# Out:
#       scene_id satellite    tra                     geometry
# 0  l5_scene_01        l5  False  POINT (119.57049 -29.09522)
# 1  l5_scene_02        l5   True    POINT (66.38197 59.88031)
# 2  l5_scene_03        l5   True    POINT (61.77425 46.04525)
# 3  l5_scene_04        l5   True   POINT (125.44233 63.95019)
# 4  l5_scene_05        l5   True   POINT (113.91528 22.58003)

# %%
fig, ax = plt.subplots(figsize=(6, 4), 
                subplot_kw={'projection': ccrs.PlateCarree()})
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.set_extent([-180, 180, -90, 90])
dset_gdf[dset_gdf['tra']].plot(ax=ax, 
                    markersize=6, 
                    color='blue',
                    label='Training set')
dset_gdf[~dset_gdf['tra']].plot(ax=ax, 
                    markersize=6, 
                    color='red',
                    label='Validation set')
ax.set_title('Training and Validation dataset')
ax.legend(loc=(0.03,0.05), fontsize=9)
ax.set_xticks(np.arange(-180, 181, 60), crs=ccrs.PlateCarree())
ax.set_yticks(np.arange(-90, 91, 30), crs=ccrs.PlateCarree())
ax.set_xlabel('Longitude'); ax.set_ylabel('Latitude')
ax.tick_params(labelsize=10)
fig.savefig('figs/tra_val_split.png', dpi=300)
