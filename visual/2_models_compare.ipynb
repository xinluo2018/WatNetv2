# %% [markdown]
# ###  comparison among existing segmentation models
# unet, deeplabv3+, hrnet

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_metrics_unet = 'model/trained/seg_models/unet_metrics_1.csv'
path_metrics_deeplabv3plus = 'model/trained/seg_models/deeplabv3plus_metrics_1.csv'
path_metrics_deeplabv3plus_mb2 = 'model/trained/seg_models/deeplabv3plus_mb2_metrics_1.csv'
metrics_unet_df = pd.read_csv(path_metrics_unet)
metrics_deeplabv3plus_df = pd.read_csv(path_metrics_deeplabv3plus)
metrics_deeplabv3plus_mb2_df = pd.read_csv(path_metrics_deeplabv3plus_mb2)
metrics_unet_df.tail() 
# metrics_deeplabv3plus_mb2_df.tail()
# Out:
#     epoch  tra_loss  tra_miou    tra_oa  val_loss  val_miou    val_oa
# 95    285  0.042776  0.943493  0.972871  0.069560  0.908438  0.940587
# 96    288  0.046812  0.936178  0.969927  0.069532  0.908152  0.940227
# 97    291  0.045711  0.941937  0.971986  0.070406  0.908050  0.939886
# 98    294  0.041704  0.933317  0.967049  0.068171  0.909022  0.942392
# 99    297  0.042989  0.938616  0.967901  0.069425  0.908157  0.940617

# %%
metrics_df = [metrics_unet_df, 
              metrics_deeplabv3plus_df, 
              metrics_deeplabv3plus_mb2_df]
colors = ['blue', 'orange', 'green']
labels = ['unet', 'deeplabv3plus', 'deeplabv3plus_mb2']

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='val_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
ax.set_title('MIoU using patch_512')
# Out:
# Text(0.5, 1.0, 'MIoU using patch_512')
